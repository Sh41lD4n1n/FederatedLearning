# %% [markdown]
# # Test Model _ver 2

# %%
#!git clone https://github.com/Sh41lD4n1n/FederatedLearning

# %%
# !pwd

# %%
#/kaggle/input/federatedlearning/FederatedLearning
#/kaggle/working

# %%
import os
os.chdir("/kaggle/input/federatedlearning")

# %%
# !pwd

# %%
#!git checkout CNN_model

# %%
import os

os.chdir("./Models/CNN_model")
#!ls
from Model import Model#,Optimizer_SGD
from Data import Data

os.chdir("../..")
# !ls

from Models.FederatedLearning.Server import server
from Models.StatisticClass import Statistic,array_mean_object

#os.chdir("../Reports")
import matplotlib.pyplot as plt
import numpy as np
#!ls

# %%
import torch.optim as optim

# %%
# !pwd

# %%
os.chdir("/kaggle/working")

# %%
# !pwd

# %%
Data.SPLITS
# Out:
# ['het',
#  'ident',
#  'random_indent',
#  'ident_same',
#  'noSplit',
#  'noSplit_test_split']

# %% [markdown]
# ## Data

# %%
d = Data(split = Data.SPLITS[0],n_workers=3,environment = "kaggle")
d1 = Data(split = Data.SPLITS[1],n_workers=3,environment = "kaggle")
d2 = Data(split = Data.SPLITS[2],n_workers=3,environment = "kaggle")
d3 = Data(split = Data.SPLITS[3],n_workers=3,environment = "kaggle")
d4 = Data(split = "noSplit",n_workers=1,environment = "kaggle")
d5 = Data(split = Data.SPLITS[-1],n_workers=3,environment = "kaggle")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(Data.SPLITS[0])
trains,tests = d.get_data()

for i,(train,test) in enumerate(zip(trains,tests)):
    plt.figure(figsize=(10, 5))

    val,counts = np.unique(train.targets,return_counts = True)
    val1,counts1 = np.unique(test.targets,return_counts = True)

    plt.subplot(121)
    plt.bar(val,counts)
    plt.subplot(122)
    plt.bar(val1,counts1)
    plt.suptitle(f"worker {i}")
    plt.show()
    print(len(train),len(test),"% of test ",len(test)/(len(train)+len(test)))
# Out:
# het
# 16660 10000 % of test  0.37509377344336087
# 16660 10000 % of test  0.37509377344336087
# 16680 10000 % of test  0.3748125937031484

# %%
print(Data.SPLITS[1])
trains,tests = d1.get_data()

for i,(train,test) in enumerate(zip(trains,tests)):
    plt.figure(figsize=(10, 5))

    val,counts = np.unique(train.targets,return_counts = True)
    val1,counts1 = np.unique(test.targets,return_counts = True)

    plt.subplot(121)
    plt.bar(val,counts)
    plt.subplot(122)
    plt.bar(val1,counts1)
    plt.suptitle(f"worker {i}")
    plt.show()
    print(len(train),len(test),"% of test ",len(test)/(len(train)+len(test)))
# Out:
# ident
# 16660 10000 % of test  0.37509377344336087
# 16660 10000 % of test  0.37509377344336087
# 16660 10000 % of test  0.37509377344336087

# %%
print(Data.SPLITS[2])
trains,tests = d2.get_data()

for i,(train,test) in enumerate(zip(trains,tests)):
    plt.figure(figsize=(10, 5))

    val,counts = np.unique(train.targets,return_counts = True)
    val1,counts1 = np.unique(test.targets,return_counts = True)

    plt.subplot(121)
    plt.bar(val,counts)
    plt.subplot(122)
    plt.bar(val1,counts1)
    plt.suptitle(f"worker {i}")
    plt.show()
    print(len(train),len(test),"% of test ",len(test)/(len(train)+len(test)))
# Out:
# random_indent
# 16666 10000 % of test  0.3750093752343809
# 16666 10000 % of test  0.3750093752343809
# 16666 10000 % of test  0.3750093752343809

# %%
print(Data.SPLITS[3])
trains,tests = d3.get_data()

for i,(train,test) in enumerate(zip(trains,tests)):
    plt.figure(figsize=(10, 5))

    val,counts = np.unique(train.targets,return_counts = True)
    val1,counts1 = np.unique(test.targets,return_counts = True)

    plt.subplot(121)
    plt.bar(val,counts)
    plt.subplot(122)
    plt.bar(val1,counts1)
    plt.suptitle(f"worker {i}")
    plt.show()
    print(len(train),len(test),"% of test ",len(test)/(len(train)+len(test)))
# Out:
# ident_same
# 16660 10000 % of test  0.37509377344336087
# 16660 10000 % of test  0.37509377344336087
# 16660 10000 % of test  0.37509377344336087

# %%
print(Data.SPLITS[4])
train,test = d4.get_data()

plt.figure(figsize=(10, 5))
val,counts = np.unique(train[0].targets,return_counts = True)
val1,counts1 = np.unique(test[0].targets,return_counts = True)

plt.subplot(121)
plt.bar(val,counts)
plt.subplot(122)
plt.bar(val1,counts1)
plt.suptitle("worker 0")
plt.show()
print(len(train[0]),len(test[0]),"% of test ",len(test[0])/(len(train[0])+len(test[0])))
# Out:
# noSplit
# 50000 10000 % of test  0.16666666666666666

# %%
print(Data.SPLITS[5])
train,test = d5.get_data()

plt.figure(figsize=(10, 5))
val,counts = np.unique(train[0].targets,return_counts = True)
val1,counts1 = np.unique(test[0].targets,return_counts = True)

plt.subplot(121)
plt.bar(val,counts)
plt.subplot(122)
plt.bar(val1,counts1)
plt.suptitle("worker 0")
plt.show()
print(len(train[0]),len(test[0]),"% of test ",len(test[0])/(len(train[0])+len(test[0])))
# Out:
# noSplit_test_split
# 50000 3330 % of test  0.06244140258766173

# %% [markdown]
# ## Model

# %%
print("train Model")
# Out:
# train Model

# %%
d = Data(split = "noSplit",n_workers=1,environment = "kaggle")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print("noSplit")
train,test = d.get_data()

plt.figure(figsize=(10, 5))
val,counts = np.unique(train[0].targets,return_counts = True)
val1,counts1 = np.unique(test[0].targets,return_counts = True)

plt.subplot(121)
plt.bar(val,counts)
plt.subplot(122)
plt.bar(val1,counts1)
plt.suptitle("worker 0")
plt.show()
print(len(train[0]),len(test[0]),"% of test ",len(test[0])/(len(train[0])+len(test[0])))
# Out:
# noSplit
# 50000 10000 % of test  0.16666666666666666

# %%
m = Model("Model")
m.set_optimizer(optim.SGD(m.net.parameters(), lr=0.01))
trainloader = d.get_data_loaders()[0]['trainloader']
testloader = d.get_data_loaders()[0]['testloader']

m.run(epoch = 100,train_loader = trainloader,test_loader = testloader)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [25:06<00:00, 15.07s/it]

# %%
print(m.stat_collector.loss[-1])
print(m.stat_collector.accuracy[-1])
m.stat_collector.loss_plot()
m.stat_collector.acc_plot()
m.stat_collector.weight_plot()
# Out:
# 0.89386085015309
# 0.6878

# %%
print("train Model")
# Out:
# train Model

# %% [markdown]
# ## Federated learning

# %% [markdown]
# ### Identical split, running with update on each iteration

# %%
def model_creator(w_num):
    print(w_num)
    name = f"FederatedModelSingleW_ident_{w_num}_"

    model = Model(name)
    return model

# %%
d = Data(split = "ident",n_workers=1,environment = "kaggle")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
"""
trains,tests = d.get_data()

for i,(train,test) in enumerate(zip(trains,tests)):
    plt.figure(figsize=(10, 5))

    val,counts = np.unique(train.targets,return_counts = True)
    val1,counts1 = np.unique(test.targets,return_counts = True)

    plt.subplot(121)
    plt.bar(val,counts)
    plt.subplot(122)
    plt.bar(val1,counts1)
    plt.suptitle(f"worker {i}")
    plt.show()"""
# Out:
# '\ntrains,tests = d.get_data()\n\nfor i,(train,test) in enumerate(zip(trains,tests)):\n    plt.figure(figsize=(10, 5))\n\n    val,counts = np.unique(train.targets,return_counts = True)\n    val1,counts1 = np.unique(test.targets,return_counts = True)\n\n    plt.subplot(121)\n    plt.bar(val,counts)\n    plt.subplot(122)\n    plt.bar(val1,counts1)\n    plt.suptitle(f"worker {i}")\n    plt.show()'

# %%
s = server(num_workers=1,data = d.get_data_loaders(),model_creator=model_creator)
s.run(n_iter=100,T=1)
# Out:
# 0
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.51s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.67s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.41s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.40s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.93s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.17s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.50s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.00s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.81s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.02s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.48s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.90s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.84s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.66s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.09s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.20s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.77s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.14s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.99s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.39s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:18<00:00, 18.53s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.52s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:17<00:00, 17.14s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.10s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.75s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.31s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.34s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.09s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.33s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.13s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.94s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.26s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.19s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.16s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.21s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.68s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.75s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.67s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.29s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.01s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.46s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:19<00:00, 19.11s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.68s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.81s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.63s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.55s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.95s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.86s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.45s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.54s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.74s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.50s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.01s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.79s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.32s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.92s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:17<00:00, 17.35s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.33s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.50s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.35s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.26s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.24s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.64s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.24s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.84s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.55s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.61s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.71s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.72s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.61s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.75s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.58s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.87s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.45s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.43s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:16<00:00, 16.04s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.06s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.45s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.56s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.61s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.65s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.27s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.20s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.72s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.05s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.85s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.57s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.94s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.83s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.02s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.57s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.81s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.39s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.77s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.71s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.25s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.57s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.75s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.30s/it]
# 100%|█████████████████████████████████████████████| 1/1 [00:15<00:00, 15.75s/it]

# %%
print(s.workers[0].model.stat_collector.loss[-1])
print(s.workers[0].model.stat_collector.accuracy[-1])
s.workers[0].model.stat_collector.loss_plot()
s.workers[0].model.stat_collector.acc_plot()
s.workers[0].model.stat_collector.weight_plot()
# Out:
# 0.9096972233132471
# 0.6797

# %% [markdown]
# ### Identical split

# %%
print("identical")
# Out:
# identical

# %%
def model_creator1(w_num):
    name = f"FederatedIdentModel_random_noSplit_{w_num}"
    #opt = Optimizer_SGD()
    preconditioner = None
    scaller = None

    model = Model(name)
    #model.set_optimizer(opt)
    #model.set_preconditioner(preconditioner)
    #model.set_scaller(scaller)
    return model

# %%
def model_creator2(w_num):
    name = f"FederatedIdentModel_ident_same_{w_num}"
    #opt = Optimizer_SGD()
    preconditioner = None
    scaller = None

    model = Model(name)
    #model.set_optimizer(opt)
    #model.set_preconditioner(preconditioner)
    #model.set_scaller(scaller)
    return model

# %%
def model_creator3(w_num):
    name = f"FederatedIdentModel_{w_num}"
    #opt = Optimizer_SGD()
    preconditioner = None
    scaller = None

    model = Model(name)
    #model.set_optimizer(opt)
    #model.set_preconditioner(preconditioner)
    #model.set_scaller(scaller)
    return model

# %%
Data.SPLITS
# Out:
# ['het',
#  'ident',
#  'random_indent',
#  'ident_same',
#  'noSplit',
#  'noSplit_test_split']

# %%
d1 = Data(split = "noSplit",n_workers=3,environment = "kaggle")
d2 = Data(split = "ident_same",n_workers=3,environment = "kaggle")
d3 = Data(split = "ident",n_workers=3,environment = "kaggle")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
data = [d1.get_data_loaders()[0],d1.get_data_loaders()[0],d1.get_data_loaders()[0]]
s = server(num_workers=3,data = data,model_creator=model_creator1)
s.run(n_iter=100,T=5)

stat_collectors = [w.model.stat_collector for w in s.workers]
stat_collector = array_mean_object(stat_collectors,"FederatedIdentModel_noSplit")
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [01:07<00:00, 13.52s/it]
# 100%|█████████████████████████████████████████████| 5/5 [01:15<00:00, 15.15s/it]
# 100%|█████████████████████████████████████████████| 5/5 [01:22<00:00, 16.53s/it]
# 100%|█████████████████████████████████████████████| 5/5 [01:41<00:00, 20.24s/it]
# 100%|█████████████████████████████████████████████| 5/5 [01:44<00:00, 20.93s/it]
# 100%|█████████████████████████████████████████████| 5/5 [01:21<00:00, 16.37s/it]
# 100%|█████████████████████████████████████████████| 5/5 [01:21<00:00, 16.22s/it]
#  20%|█████████                                    | 1/5 [00:16<01:05, 16.42s/it]

# %%
print(stat_collector.loss[-1])
print(stat_collector.accuracy[-1])
stat_collector.loss_plot()
stat_collector.acc_plot()

# %%
s = server(num_workers=3,data = d2.get_data_loaders(),model_creator=model_creator2)
s.run(n_iter=100,T=5)

stat_collectors = [w.model.stat_collector for w in s.workers]
stat_collector = array_mean_object(stat_collectors,"FederatedIdentModel_ident_same")

# %%
print(stat_collector.loss[-1])
print(stat_collector.accuracy[-1])
stat_collector.loss_plot()
stat_collector.acc_plot()

# %%
s = server(num_workers=3,data = d3.get_data_loaders(),model_creator=model_creator3)
s.run(n_iter=100,T=5)

stat_collectors = [w.model.stat_collector for w in s.workers]
stat_collector = array_mean_object(stat_collectors,"FederatedIdentModel_ident")

# %%
print(stat_collector.loss[-1])
print(stat_collector.accuracy[-1])
stat_collector.loss_plot()
stat_collector.acc_plot()

# %% [markdown]
# ## Heterogenious

# %%
def model_creator(w_num):
    name = f"FederatedHetModel_{w_num}"
    #opt = Optimizer_SGD()
    preconditioner = None
    scaller = None

    model = Model(name)
    #model.set_optimizer(opt)
    #model.set_preconditioner(preconditioner)
    #model.set_scaller(scaller)
    return model

# %%
d = Data(split = "het",n_workers=3,environment="")

# %%
trains,tests = d.get_data()

for i,(train,test) in enumerate(zip(trains,tests)):
    plt.figure(figsize=(10, 5))

    val,counts = np.unique(train.targets,return_counts = True)
    val1,counts1 = np.unique(test.targets,return_counts = True)

    plt.subplot(121)
    plt.bar(val,counts)
    plt.subplot(122)
    plt.bar(val1,counts1)
    plt.suptitle(f"worker {i}")
    plt.show()

# %%
len(trains[0]),len(trains[1]),len(trains[2]),len(trains[0])+len(trains[1])+len(trains[2])

# %%
len(tests[0]),len(tests[1]),len(tests[2]),len(tests[0])+len(tests[1])+len(tests[2])

# %%
s = server(num_workers=3,data = d.get_data_loaders(),model_creator=model_creator)
s.run(n_iter=100,T=5)

# %%
stat_collectors = [w.model.stat_collector for w in s.workers]
stat_collector = array_mean_object(stat_collectors,"heterogeneous")
